# %%
from urllib import request
import time
import json
import os

# %%
ISSN = ['09725423']
YEAR_ID = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['09752404']
YEAR_ID = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['20381026']
YEAR_ID = ['2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['20385366']
YEAR_ID = ['2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['21506698']
YEAR_ID = ['1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['00990086']
YEAR_ID = ['1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['15337979']
YEAR_ID = ['1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['10401628']
YEAR_ID = ['1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['1941126X']
YEAR_ID = ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['19411278']
YEAR_ID = ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['15214672']
YEAR_ID = ['1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['15479684']
YEAR_ID = ['1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['22879099']
YEAR_ID = ['2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['22874577']
YEAR_ID = ['2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['19882858']
YEAR_ID = ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['11321873']
YEAR_ID = ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['22396152']
YEAR_ID = ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['22809112']
YEAR_ID = ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['02196492']
YEAR_ID = ['2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['17936926']
YEAR_ID = ['2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['15220222']
YEAR_ID = ['1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['1574180X']
YEAR_ID = ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['15741796']
YEAR_ID = ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['19458851']
YEAR_ID = ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['1945886X']
YEAR_ID = ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['16067509']
YEAR_ID = ['2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['23099119']
YEAR_ID = ['2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['17485681']
YEAR_ID = ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['17485673']
YEAR_ID = ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['10829873']
YEAR_ID = ['1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['20908423']
YEAR_ID = ['2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['20908431']
YEAR_ID = ['2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['23200057']
YEAR_ID = ['2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['23216654']
YEAR_ID = ['2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['23739231']
YEAR_ID = ['2015', '2016', '2017', '2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['1013090X']
YEAR_ID = ['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['21731071']
YEAR_ID = ['2016', '2017']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['16962508']
YEAR_ID = ['2016', '2017']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['23450053']
YEAR_ID = ['2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['02042061']
YEAR_ID = ['2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['05071925']
YEAR_ID = ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['13346938']
YEAR_ID = ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['18025951']
YEAR_ID = ['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['18025943']
YEAR_ID = ['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['20088310']
YEAR_ID = ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['20088302']
YEAR_ID = ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['01576895']
YEAR_ID = ['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['21646058']
YEAR_ID = ['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['1947945X']
YEAR_ID = ['2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['19479468']
YEAR_ID = ['2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['21619417']
YEAR_ID = ['2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['07307187']
YEAR_ID = ['2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['19375034']
YEAR_ID = ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['19386389']
YEAR_ID = ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['01033786']
YEAR_ID = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['19815344']
YEAR_ID = ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['14139936']
YEAR_ID = ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['03609081']
YEAR_ID = ['1938', '1939', '1940', '1941', '1942', '1943', '1944', '1945', '1946', '1947', '1948', '1949', '1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['01639374']
YEAR_ID = ['1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['0898008X']
YEAR_ID = ['1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['1195096X']
YEAR_ID = ['1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['2174081X']
YEAR_ID = ['2012', '2013', '2014', '2015', '2016', '2017', '2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['18880967']
YEAR_ID = ['2012', '2013', '2014', '2015', '2016', '2017', '2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['18463312']
YEAR_ID = ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['18469418']
YEAR_ID = ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['15148327']
YEAR_ID = ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['18511740']
YEAR_ID = ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['22807934']
YEAR_ID = ['2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['22839364']
YEAR_ID = ['2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['14112272']
YEAR_ID = ['2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['25389866']
YEAR_ID = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['01200976']
YEAR_ID = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['18684394']
YEAR_ID = ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['18684408']
YEAR_ID = ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()

# %%
ISSN = ['1534150X']
YEAR_ID = ['2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
text_sample = ''
URL_PATTERN = 'https://api.elsevier.com/content/search/scopus?field=dc:identifier,dc:title,prism:doi,authkeywords,affiliation-country&query=issn({})&count=200&date={}&httpAccept=application/json&apiKey=ad4e12568b69167a2d25213b52923901&insttoken=0363e8707601cf3e7f27138d2b25f9e4'

# %%
if __name__ == '__main__':
    for issn in ISSN:
        route = "./LatinxMeta/outputs5/{i}".format(i = issn)
        if not (os.path.exists(route)):
            os.makedirs(route)
            for y_id in  YEAR_ID:
                if not (os.path.exists(route + "/" + issn + "_" + y_id + ".json")):
                    try:
                        url = URL_PATTERN.format(issn, y_id) 
                        response = request.urlopen(url)   
                        scopus_pull = response.read().decode('utf8')
                        
                        time.sleep(1)
                        
                        full_json = json.loads(scopus_pull)

                        with open(route + "/" + issn + "_" + y_id + ".json", 'w') as scopus:
                            scopus.write(json.dumps(full_json))
                     
                    except Exception as ex:
                        print(str(ex))
                        print(str(url))
                        print(str(response))
                        print("=========================================================")
                        exit()
